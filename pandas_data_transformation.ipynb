# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/employees.csv')

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df.Gender.value_counts()
# Out:
# Gender
# Female    431
# Male      424
# Name: count, dtype: int64

# %%
#check Nan value sum
df.Gender.isna().sum()
# Out:
# 145

# %%
#categorigal for gender
df['Gender2'] = pd.Categorical(df.Gender)

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team Gender2
# 0              True        Marketing    Male
# 1              True              NaN    Male
# 2             False          Finance  Female
# 3              True          Finance    Male
# 4              True  Client Services    Male

# %%
df.memory_usage()
# Out:
# Index                 128
# First Name           8000
# Gender               1124
# Start Date           8000
# Last Login Time      8000
# Salary               8000
# Bonus %              8000
# Senior Management    8000
# Team                 8000
# Gender2              1124
# dtype: int64

# %%
import random

# %%
df['Score'] = pd.Series(random.choices(['Very Low','Low','Medium','High','Very High'],k=1000))

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team Gender2      Score
# 0                True             Marketing    Male   Very Low
# ...

# %%
df.dtypes
# Out:
# First Name             object
# Gender               category
# Start Date             object
# Last Login Time        object
# Salary                  int64
# Bonus %               float64
# Senior Management      object
# Team                   object
# Gender2              category
# Score                  object
# dtype: object

# %%
# pd.Categorical(df.Score)
# pd.Categorical(df.Score, categories=['Very Low','Low','Medium','High','Very High'],ordered=True)
df['Score2'] = pd.Categorical(df.Score, categories=['Very Low','Low','Medium','High','Very High'],ordered=True)

# %%
sum(df.Score2>'Medium')
# Out:
# 356

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team Gender2      Score     Score2    Score2)
# 0              True        Marketing    Male  Very High  Very High  Very High
# 1              True              NaN    Male   Very Low   Very Low   Very Low
# 2             False          Finance  Female   Very Low   Very Low   Very Low
# 3              True          Finance    Male        Low        Low        Low
# 4              True  Client Services    Male        Low        Low        Low

# %%
df.Salary.min()
# Out:
# 35013

# %%
df.Salary.max()
# Out:
# 149908

# %%
#make cat of Salari 35 -150
# pd.cut(df.Salary,bins= [35000,50000,75000,100000,125000,150000],
#      labels = ['Very Low','Low','Medium','High','Very High'])
df['cat_salary'] = pd.cut(df.Salary,bins= [35000,50000,75000,100000,125000,150000],
      labels = ['Very Low','Low','Medium','High','Very High'])

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team Gender2      Score     Score2  \
# 0                True             Marketing    Male  Very High  Very High
# ...

# %%
df.memory_usage()
# Out:
# Index                 128
# First Name           8000
# Gender               1124
# Start Date           8000
# Last Login Time      8000
# Salary               8000
# Bonus %              8000
# Senior Management    8000
# Team                 8000
# Gender2              1124
# Score                1212
# Score2               1212
# Score2)              1212
# cat_salary           1212
# dtype: int64

# %%
df.drop(['Score2)'],axis=1)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team Gender2      Score     Score2  \
# 0                True             Marketing    Male  Very High  Very High
# ...
